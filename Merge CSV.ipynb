# %%
# Dependencies

import pandas as pd

# %%
# Define the path of each file:

path_one = "Cycong/01.csv"
path_two = "Cycong/02.csv"
path_three = "Cycong/03.csv"
path_four = "Cycong/04.csv"
path_five = "Cycong/05.csv"
path_six = "Cycong/06.csv"
path_seven = "Cycong/07.csv"
path_eight = "Cycong/08.csv"
path_nine = "Cycong/09.csv"
path_ten = "Cycong/10.csv"

# %%
# Read our Data file with the pandas library

one_df = pd.read_csv(path_one)
two_df = pd.read_csv(path_two)
three_df = pd.read_csv(path_three)
four_df = pd.read_csv(path_four)
five_df = pd.read_csv(path_five)
six_df = pd.read_csv(path_six)
seven_df = pd.read_csv(path_seven)
eight_df = pd.read_csv(path_eight)
nine_df = pd.read_csv(path_nine)
ten_df = pd.read_csv(path_ten)

# %%
one_df.columns
# Out:
# Index(['Unnamed: 0', 'Listing ID', 'S', 'Sub Type', 'St#', 'St Name', 'City',
#        'MLS Area', 'SLC', 'L/C Price', 'Price Per Square Foot', 'Br/Ba',
#        'Sqft', 'YrBuilt', 'Ac/LSqft', 'DOM/CDOM', 'View YN', 'Pool Private YN',
#        'BAC', 'Contract Status Change Date', 'MLS'],
#       dtype='object')

# %%
merge_table_one_two = pd.merge(one_df, two_df, on="Listing ID", how="outer")
merge_table_one_two
# Out:
#      Unnamed: 0_x  Listing ID  S_x Sub Type_x   St#_x               St Name_x  \
# 0             1.0   180048066    S     MANL/D      12       Via Veneto    #12
# 1             1.0   180047253    S    CONDO/A    1653     Pentecost Way    #1
# 2             1.0   180046958    S    CONDO/A    6101    Adelaide Ave    #107
# 3             1.0   180047651    S    CONDO/A   589 N         Johnson    #137
# 4             1.0   180051931    S        SFR    3138           Roadrunner
# 5             1.0   180048621    S    CONDO/A    9859  Mission Viejo Ct    #3
# 6             1.0   180046204    S    CONDO/A    5648        Amaya Dr    #136
# 7             1.0   180047374    S    CONDO/A    6780       Friars Rd    #102
# 8             1.0  MD18209408    S      SFR/D  1108 S              Berry DR
# 9             1.0   180047682    S    CONDO/A    7747    Margerum Ave    #232
# 10            1.0  MC18206507    S     MANL/D   16932             Quartz ST
# ...

# %%
merge_table_one_two.to_csv("fileOne.csv", index=False, header=True)
